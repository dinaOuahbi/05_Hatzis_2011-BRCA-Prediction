# %%
! ls
# Out:
#  05_hatzis_2011_clinical.csv    05_hatzis_2011_suppData.csv
#  05_hatzis_2011_gex.csv        'analysis and ML.ipynb'
#  05_hatzis_2011.ipynb	        GSE25055_series_matrix.csv
#  05_hatzis_2011_merge.csv       nihms905547.pdf
#  05_hatzis_2011_merging.ipynb

# %%
import pandas as pd
df = pd.read_csv('GSE25055_series_matrix.csv', skiprows=87, index_col=0)
df.head()
# Out:
#            GSM615096  GSM615097  GSM615098  GSM615099  GSM615100  GSM615101  \
# ID_REF
# 1007_s_at  12.359267  12.613243  11.551397  11.828700  11.983987  11.968264
# 1053_at     8.021741   7.842947   8.776267   9.523877   6.836237   8.665255
# 117_at      8.294244   5.474758   8.197121   7.907263   8.625010   7.480015
# 121_at     10.840949  11.715159  10.715077  10.750475  10.827725  10.767155
# 1255_g_at   7.874062   7.347955   6.523880   6.478643   7.336754   6.641128
#
#            GSM615102  GSM615103  GSM615104  GSM615105  ...  GSM615396  \
# ID_REF                                                 ...
# 1007_s_at  12.941168  12.564150  12.346389  12.582410  ...  12.573303
# 1053_at     8.413069   8.292229   8.204654   7.789927  ...   8.857717
# 117_at      8.780554   9.817384   8.328537   7.512418  ...   8.652585
# 121_at     10.945211  10.905835  11.074558  10.777823  ...  11.051351
# 1255_g_at   7.988518   6.809615   6.271495   6.860993  ...   7.069973
#
# ...

# %%
df = df.T

# %%
df.drop('!series_matrix_table_end', axis=1, inplace=True)

# %%
df.reset_index(inplace=True)

# %%
df.rename(columns={'index':'patient_ID'}, inplace=True)

# %%
df.head(2)
df.shape
# Out:
# (310, 22284)

# %%
cd = pd.read_csv('05_hatzis_2011_clinical.csv')
cd.shape
# Out:
# (310, 20)

# %%
merg = pd.merge(cd, df, on='patient_ID')
merg.head()
# Out:
#   patient_ID   age er_ihc pr_ihc her2                   NAC stage nodal_stat  \
# 0  GSM615096  37.8      P      P    N  Taxane/Anthracycline    T2         N1
# 1  GSM615097  45.8      P      P    N  Taxane/Anthracycline    T3         N1
# 2  GSM615098  40.7      N      N    N  Taxane/Anthracycline    T3         N0
# 3  GSM615099  40.8      N      N    N  Taxane/Anthracycline    T2         N1
# 4  GSM615100  35.5      P      P    N  Taxane/Anthracycline    T3         N1
#
#   ajcc_stage             grade  ... AFFX-r2-Hs28SrRNA-5_at  \
# 0        IIB                 2  ...               9.047564
# 1       IIIA                 2  ...               8.765575
# 2        IIB                 3  ...               9.450242
# 3        IIB   4=Indeterminate  ...               8.466331
# 4       IIIA                 2  ...               8.721290
#
#   AFFX-r2-Hs28SrRNA-M_at  AFFX-r2-P1-cre-3_at  AFFX-r2-P1-cre-5_at  \
# 0              11.274337            17.356685            17.004035
# ...

# %%
merg.shape
# Out:
# (310, 22303)

# %%
#merg.to_csv('05_hatzis_2011_merge.csv', index=False)

# %%
df.head()
# Out:
# ID_REF patient_ID  1007_s_at   1053_at    117_at     121_at  1255_g_at  \
# 0       GSM615096  12.359267  8.021741  8.294244  10.840949   7.874062
# 1       GSM615097  12.613243  7.842947  5.474758  11.715159   7.347955
# 2       GSM615098  11.551397  8.776267  8.197121  10.715077   6.523880
# 3       GSM615099  11.828700  9.523877  7.907263  10.750475   6.478643
# 4       GSM615100  11.983987  6.836237  8.625010  10.827725   7.336754
#
# ID_REF   1294_at   1316_at   1320_at  1405_i_at  ...  AFFX-r2-Hs28SrRNA-5_at  \
# 0       8.341292  8.256335  6.485966   6.495728  ...                9.047564
# 1       9.419005  7.983681  7.330512   7.332244  ...                8.765575
# 2       9.297479  7.820261  6.423794  10.066291  ...                9.450242
# 3       8.698516  7.526617  7.276040  10.399704  ...                8.466331
# 4       9.599059  8.312127  6.832232   7.090151  ...                8.721290
#
# ID_REF  AFFX-r2-Hs28SrRNA-M_at  AFFX-r2-P1-cre-3_at  AFFX-r2-P1-cre-5_at  \
# ...

# %%
df.to_csv('05_hatzis_2011_gex.csv')
