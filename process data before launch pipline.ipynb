# %%
import pandas as pd
import numpy as np

# %%
! ls
# Out:
# 05_hatzis_2011_Recist_genes.csv  SelectKBestFisherExactTest.py
# p3_nested10CV_mink.py		 Untitled.ipynb

# %%
df = pd.read_csv('05_hatzis_2011_Recist_genes.csv')
df.head()
# Out:
#   patient_ID  RECIST  1007_s_at   1053_at    117_at     121_at  1255_g_at  \
# 0  GSM615096       0  12.359267  8.021741  8.294244  10.840949   7.874062
# 1  GSM615097       0  12.613243  7.842947  5.474758  11.715159   7.347955
# 2  GSM615098       0  11.551397  8.776267  8.197121  10.715077   6.523880
# 3  GSM615099       1  11.828700  9.523877  7.907263  10.750475   6.478643
# 4  GSM615100       0  11.983987  6.836237  8.625010  10.827725   7.336754
#
#     1294_at   1316_at   1320_at  ...  AFFX-r2-Hs28SrRNA-5_at  \
# 0  8.341292  8.256335  6.485966  ...                9.047564
# 1  9.419005  7.983681  7.330512  ...                8.765575
# 2  9.297479  7.820261  6.423794  ...                9.450242
# 3  8.698516  7.526617  7.276040  ...                8.466331
# 4  9.599059  8.312127  6.832232  ...                8.721290
#
#    AFFX-r2-Hs28SrRNA-M_at  AFFX-r2-P1-cre-3_at  AFFX-r2-P1-cre-5_at  \
# 0               11.274337            17.356685            17.004035
# ...

# %%
df.shape
# Out:
# (306, 22285)

# %%
checkifthereisnan = df[df.isna().any(axis=1)]

# %%
df.rename(columns={'patient_ID':'Patient'}, inplace=True)

# %%
dico = {0.0:'NonResponder', 1.0:'Responder'}
df['RECIST'] = df['RECIST'].map(dico)

# %%
df.rename(columns={'RECIST':'response'}, inplace=True)

# %%
df.head()
# Out:
#      Patient      response  1007_s_at   1053_at    117_at     121_at  \
# 0  GSM615096  NonResponder  12.359267  8.021741  8.294244  10.840949
# 1  GSM615097  NonResponder  12.613243  7.842947  5.474758  11.715159
# 2  GSM615098  NonResponder  11.551397  8.776267  8.197121  10.715077
# 3  GSM615099     Responder  11.828700  9.523877  7.907263  10.750475
# 4  GSM615100  NonResponder  11.983987  6.836237  8.625010  10.827725
#
#    1255_g_at   1294_at   1316_at   1320_at  ...  AFFX-r2-Hs28SrRNA-5_at  \
# 0   7.874062  8.341292  8.256335  6.485966  ...                9.047564
# 1   7.347955  9.419005  7.983681  7.330512  ...                8.765575
# 2   6.523880  9.297479  7.820261  6.423794  ...                9.450242
# 3   6.478643  8.698516  7.526617  7.276040  ...                8.466331
# 4   7.336754  9.599059  8.312127  6.832232  ...                8.721290
#
#    AFFX-r2-Hs28SrRNA-M_at  AFFX-r2-P1-cre-3_at  AFFX-r2-P1-cre-5_at  \
# ...

# %%
df.to_csv('05_hatzis_2011_Recist_genes.csv', index = False, sep = '\t')
